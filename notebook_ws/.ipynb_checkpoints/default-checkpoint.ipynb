# %% [markdown]
# # BSCH - AI & Robotics
# ### Griffith College Dublin, 2026
#
# <img src="images/navigation_course_details.png"/>
#
# ##  Group Project 60%
#
# *Remember to check Moodle for your group allocation.*
#
#
# **In this rosject, you will apply everything you've learned in the ROS Navigation course to a TurtleBot3 robot.**
#
# You can practice with both a simulation and a real robot. You can book sessions to connect remotely to a TurtleBot in Barcelona, Spain. Or you can connect to the TurtleBot3 Burger during the labs.
#
#
# Essentially, in this project, you will have to:
#
# * Apply all of the theory given in the course
# * Follow the steps provided below
# * Do as many tests as needed in the simulation environment until it works
#
# To finish this project successfully, follow the steps below.
#
# **Remember to:**
# - [ ] Create your packages and code in the simulation environment as you have been doing throughout the course.
# - [ ] Use the consoles to gather information about the status of the simulated and real robot.
# - [ ] Use the IDE to create your files and execute them through the consoles, observing the results on the simulation screen. You can use other consoles to watch calls to topics, services, or action servers.
# - [ ] Come back to the rosject at any time and continue working where you left off. Everything that you create in this unit will be automatically saved in your space.
# - [ ] Press the restart button in the simulation window if you need to reset the position of the robot.
# - [ ] Use the debugging tools to try to find what is not working and why (for instance, the Rviz tool is very useful for this purpose).
# - [ ] Keep track of time! You only have 8hr per day to work on the Rosject. Manage your time wisely!
#
#
# ### Issues?
# See the [Troubleshooting section](default.ipynb#Troubleshooting) below for most common issues, and if your issue isn't there, ask me in the lab.

# %% [markdown]
# ### TurtleBot3 Topics
#
# **Sensors**
# * Laser sensor: TurtleBot3 has an RPLIDAR, which provides information about the objects that it detects in its range. The value of the sensor is provided through the topic */scan*.
# * Odometry: The odometry of the robot can be accessed through the */odom* topic.
# * Camera: The camera image on the TurtleBot3 can be accessed through the topic */cv_camera/image_raw*.
#
# **Actuators**
# * Speed: You can send speed commands to move the robot through the topic */cmd_vel*.

# %% [markdown]
# ## How to Proceed
#
# This rosject is composed of five sections and an Appendix explaining how to connect to the real robot. *You should complete the first four sections when the ROS Navigation in 5 Days course first, before attempting this project.* These steps will ensure that you have practiced and created all of the structures asked about in this project.
#
# * **SECTION I:** Create a map of the environment **25 marks**
# * **SECTION II:** Localize the robot **20 marks**
# * **SECTION III:** Create a Path Planning System **15 marks**
# * **SECTION IV:** Additional Tasks (Groups of 3) **20 marks**
# * **SECTION V:** Demonstrate your project **20 marks**
#
#
#
# ## Try in Simulation First
#
# Use the simulation to test your code while you get the project's exercises done.
#
# To launch the simulation, do the following:
#
# 1. Open a terminal by pressing on the *terminal icon* on the bottom left side of the screen:
# <img src="images/open_terminal.png" width="50" height="50"/>
# <br>
#
# 2. Type the following command that launches the simulation

# %%
roslaunch realrobotlab main.launch

# %% [markdown]
# 3. To see the simulation, press the Gazebo button on the bottom of the screen and *Open gazebo*:
# <img src="images/open_gazebo.png" width="50" height="50"/>
#
# **Wait around 90 seconds maximum** for the simulation to appear in the Gazebo window. If you only see grey, try zooming out.
#
# <img src="images/gazeboenvironment.png"/>

# %% [markdown]
# # Package Creation
#
# Create new packages all with *rospy* as a dependency
# 1.	project_mapping
# 2.	project_localization
# 3.	project_planning

# %% [markdown]
# # SECTION I: Mapping - 25 marks
#
# The first thing you need in order to navigate autonomously with a robot is a map of the environment.
#
# In this section, you will practice how to map the environment around the robot. Your goal is to save this map file in order to use it for localization and navigation.
#
# ### Tasks:
#
# 1.	5% - Create a script that moves the robot around using simple */cmd_vel* publishing. The robot should move at a linear velocity of 0.6. If an obstacle is detected within less than a meter, the turtlebot should turn 90 degrees and continue moving at 0.6 velocity.
# <ul>
#     <li> <u>Documentation: </u>
#         <ul>
#             <li> Include a screenshot of the command used to run your script, and appropriate comment. </li>
#         </ul>
#     </li>
# </ul>
# <br>
# 1. 5% - Create an **Rviz config file** showing various elements related to mapping. You may need to update this as you progress with the section.
# <ul>
#     <li> Rviz config file name: <b>project_mapping_rviz.rivz</b> </li>
#     <li> Save the correct configuration of the corresponding elements linked to appropriate topics where possible. (See tip below for list of elements).
#     </li>
#     <li> <u>Documentation: </u>
#         <ul>
#             <li> Include a screenshot and appropriate comment. </li>
#         </ul>
#     </li>
# </ul>
# <br>
# 1. 5% - Create a launch file that will launch the **slam_gmapping** node and add the necessary **parameters** in order to properly configure the slam_gmapping node.<ul>
#     <li> Launch file name: <b>project_mapping.launch</b> </li>
#     <li> Param file name: <b>project_mapping_params.yaml</b> </li>
#     <li>Contents: Edit 5 of the default parameters</li>
#     <li><u>Documentation:</u> Explain the effect of the editing of the 5 default parameters in the yaml file and include screenshots of the commands used to run the scripts.</li>
#     </ul> <br>
#
# 1. 5% - Launch the slam_gmapping node and **create a map** of the simulated environment. Then, **save the map** that you've just created.
# <ul>
#     <li> Map files names:
#         <ul>
#             <li> <b>project_mapping_map.pgm</b> </li>
#             <li> <b>project_mapping_map.yaml</b> </li>
#         </ul>
#     </li>
#     <li> <u>Documentation: </u>
#         <ul>
#             <li> Explain the parameters which appear in project_mapping_map.yaml</li>
#             <li> Include a screenshot of the pgm file.</li>
#         </ul>
#     </li>
# </ul><br>
#
# 1. 5% - Create a launch file that launches the map_server node
# <ul>
#     <li> Launch file name:
#         <ul>
#             <li> <b>map_provider.launch</b> </li>
#         </ul>
#     </li>
#     <li> <u>Documentation: </u>
#         <ul>
#             <li> Explain the parameters used in map_provider.launch</li>
#         </ul>
#     </li>
# </ul>
#
#
#
#
# ### Tips
#
# **1. Create a launch file uses cmd_vel publishing to move the robot at a linear velocity of 0.6, and when an obstacle is detected rotates 90 degrees and continues moving at a speed of 0.6.**
#
# - When you perform rostopic list, /cmd_vel should be one of the topics being published by the turtlebot.
# - This topic controls the velocities of the robot. By publishing to this topic, you can control the movement of your turtlebot using Twist for linear movement.
# - To detect obstactles, read the information from the Lidar sensor using the topic /scan.
#
# **2. Create an Rviz configuration file**
# <ul>
#     <li>Rviz config file contents: Save the correct configuration of the following elements linked to appropriate topics where possible:
#         <ul>
#             <li>GlobalOptions</li>
#             <li>Grid</li>
#             <li>Map</li>
#             <li>RobotModel</li>
#             <li>TF</li>
#             <li>LaserScan</li>
#         </ul>
#             </li>
# </ul>
#
# Hint: Ros Navigation in 5 days Ex 2.1
#
#
# **3. Create the launch file for the gmapping node.**
#
# In the mapping section (Chapter 2) of the ROS Navigation in 5 days course, you've seen how to create a launch file for the slam_gmapping node. You've also seen some of the most important parameters to set. So, in this step, you'll have to create a launch file for the *slam_gmapping* node and add the parameters that you think you need to set.
#
# Here you can see a full list of parameters that you can set to configure the slam_gmapping node: http://docs.ros.org/hydro/api/gmapping/html/
#
#
# Hint: section 2.8

# %% [markdown]
# **4. Launch the node using the launch file that you've just created, and create a map of the environment.**
#
# In order to move the robot around the environment, you can use either the launch file from task 1, or the keyboard teleop. To launch the keyboard teleop, just execute the following command:

# %%
roslaunch turtlebot_teleop keyboard_teleop.launch

# %% [markdown]
# Also, remember to launch rviz and add the proper displays in order to visualize the map you are generating. You should get something like this in rviz:
#
# <img src="images/RRL_nav_mapping_small.png"/>
#
# Now, start moving the robot around the environment to create the map.
#
# If you are having difficulty generating a proper map, check the *maxUrange* parameter in the launch file of the *slam_gmapping* node. This parameter sets the maximum range of the laser scanner that is used for map building. If this is a small value, the robot can't get enough data to know where it is, so it may get lost. This will cause some strange issues during the mapping process, such as the robot readjusting its position incorrectly.
#
#
# Once you modify this parameter and relaunch the *slam_gmapping* node, you should get something like this in rviz:
#
# <img src="images/RRL_nav_mapping.png"/>
#
# Now, you will be able to map the environment much more easily.
#
#
#
# **4. Then, save the Map.**
#
# Create a directory in your package named maps, and save the map files there. Your map image file should look something similar to this:
#
# <img src="images/my_map.png"/>
#
# *Hint:*
# <ul>
#     <li>Section 2.4</li>
#     <li>Make sure all relevant topics are being published (show screen shot) </li>
#     </ul>
#
# **5. Create a launch file that launches the map_server node**
#
# The map you've just created will be used by other nodes (this means it'll be used in further steps) in order to perform navigation.
#
# Therefore, you'll need to create a launch file in order to provide the map. As you know, this is done through the *map_server* node and will take as an argument a yaml map file.
#
# Finally, launch this file and check that it's really providing the map.
#
# *Hint: Section 2.5*

# %% [markdown]
# # SECTION II: Localization - 20 marks
#
# In this section, you will localize the robot using the *amcl* node. This section has 3 steps:
#
#
# 1. 5% - Save a copy of the Rviz configuration that you use in **project_localisation_rviz.rviz**
# <ul> <li> <u> Documentation:</u>  Include a screenshot and appropriate comment. </li> </ul> <br>
#
# 2. 10% - Create a **launch file** that will launch the *amcl* node and add the necessary parameters in order to properly configure the *amcl* node.
#
#
# 3. 5% - Launch the node and check that the robot properly localizes itself in the environment.
# <ul>
#     <li> <u> Documentation:</u>
#        <ul>
#            <li>Provide a screen capture of
#         <ul>
#             <li> the dispersed particle cloud </li>
#             <li> it progressively getting smaller </li>
#             <li> it localised to the robot. </li>
#         </ul>
#        </li>
#        <li> Comment on the outcome, which may or may not be successful. </li>
#         </ul> </li>
# </ul> <br>
#
# ### Tips:
#
# **1. Save a copy of the Rviz configuration**
#
# Your configuration should have the following items:<ul>
#     <li>PoseArray </li>
#     <li>any other appropriate items </li>
# </ul>
#
#
# **2. Create a launch file for the *amcl* node**
#
# In the localization section (Chapter 3) of the *ROS Navigation in 5 Days course*, you saw how to create a launch file for the *amcl* node. You've also seen some of the most important parameters to set. So, in this step, you'll have to create a launch file for the amcl node and add the parameters you think you need to set.
#
# Here you can see a full list of parameters that you can set to configure the amcl node: http://wiki.ros.org/amcl
#
# Remember that before setting the amcl node parameters, you'll need to load the map created in Section 1. For that, you'll just need to include the launch you've created in Section 1 in the amcl node launch file in order to provide the map to other nodes.
#
# **3. Launch the node and check that the TurtleBot3 robot correctly localizes itself in the map.**
#
# Launch the node and check in rviz that the TurtleBot3 robot correctly localizes itself in the map.
#
# In order to check that the localization works fine, move the robot around the environment and check that the particle cloud keeps getting smaller the more you move the robot. If you've done all of the previous steps correctly, you should see something like this in rviz:
#
# Dispersed particles:
#
# <img src="images/RRL_nav_amcl_spread.png"/>
#
# Closer particles:
#
# <img src="images/RRL_nav_amcl_tight.png"/>
#
#    *Hints:*
# <ul>
#     <li>Ex 3.1 to 3.12 </li>
#     <li>Start with the robot in a room for faster localization </li>
# </ul>

# %% [markdown]
# # SECTION III: Path Planning - 15 marks
#
# In this section, you will create a path planning system using the *move_base* node in order to navigate autonomously.
#
# Complete the following tasks:
#
# 1. 2.5% - Save a copy of the Rviz configuration that you use in **project_planning_rvis.rviz**.
#     + <u>Documentation</u>:
#         + Include a screenshot and appropriate comment.
# <br><br>
#
# 2. 5% - Create a **launch file** that will launch the *move_base* node, and the necessary parameter files in order to properly configure the *move_base* node.
# <ul>
#     <li>Naming:
#         <ul> <li><b>project_move_base.launch</b></li>
#             <li> <b>project_move_base_params.yaml</b></li>
#             </ul></li>
#     <li><u>Documentation:</u>
# <ul><li>Provide supporting screen shots and high-level explanation </li></ul>
# </li>
#     </ul>
#     <br>
# 4. 2.5% -  Create the necessary parameter files in order to properly configure the global and local costmaps.
# 5. 2.5% - Create the necessary parameter files in order to properly configure the global and local planners.
# 6. 2.5% - Launch the node and check that everything works fine.
#     + Launch file name: **project_planning_send_goal.launch**
#     + <u>Documentation:</u>
#         + Provide supporting screenshots and high level explanation.

# %% [markdown]
# ### Tips:
#
#
# **1. Rviz Configuration file**
#
# Your configuration file should have the following items
# <ul>
#     <li>a map for both local and global costmaps (choose difference colour schemes for each). </li>
#     <li>a path for both local and global plans (choose different colours for each)</li>
#     <li>PoseArray </li>
#     <li>any other appropriate items</li>
# </ul>
#
# **2. Create the launch file for the move_base node.**
#
# In the Path Planning section (Chapter 4) of the *ROS Navigation in 5 Days course*, you saw how to create a launch file for the *move_base* node. So, in this step, you'll have to create a launch file for the *move_base* node and add the parameters and the parameter files required.
#
# Here you have an example of the *move_base.launch* file *(note in this example the package is called 'my_turtlebot_localization' etc and your package should be named 'project_localization')*:

# %%
<launch>
  <!--- Run AMCL -->
  <include file="$(find my_turtlebot_localization)/launch/my_turtlebot_localization.launch" />

  <!-- Run move_base -->
  <node pkg="move_base" type="move_base" respawn="false" name="move_base" output="screen">
    <rosparam file="$(find my_turtlebot_path_planning)/config/move_base_params.yaml" command="load" />
    <rosparam file="$(find my_turtlebot_path_planning)/config/costmap_common_params.yaml" command="load" ns="global_costmap" />
    <rosparam file="$(find my_turtlebot_path_planning)/config/costmap_common_params.yaml" command="load" ns="local_costmap" />
    <rosparam file="$(find my_turtlebot_path_planning)/config/local_costmap_params.yaml" command="load" />
    <param name="local_costmap/width" value="10.0"/>
    <param name="local_costmap/height" value="10.0"/>
    <rosparam file="$(find my_turtlebot_path_planning)/config/global_costmap_params_map.yaml" command="load" />
    <rosparam file="$(find my_turtlebot_path_planning)/config/dwa_local_planner_params.yaml" command="load" />
    <rosparam file="$(find my_turtlebot_path_planning)/config/global_planner_params.yaml" command="load" />

    <param name="base_global_planner" value="navfn/NavfnROS" />
    <param name="base_local_planner" value="dwa_local_planner/DWAPlannerROS" />
    <param name="controller_frequency" value="5.0" />
    <param name="controller_patience" value="15.0" />
  </node>

</launch>

# %% [markdown]
# **3. Create the move_base_params.yaml file**
#
# *Hint: Section 4.2*
#
# **4. Create the costmap_common_params.yaml, the global_costmap_params.yaml, and the local_costmap_params.yaml files**
#
# *Hint: Section 4.5*
#
# **5. Create the navfn_global_planner_params.yaml and dwa_local_planner_params.yaml files**
#
# *Hint: Sections 4.3 and 4.4*
#
# **6. Launch the node and check that everything works fine**
#
# - Once you think your parameter files are correct, launch the node and test that the path planning works fine.
# - Check that the robot can plan trajectories and navigate to different points in the environment.
# - Use the 2D Pose Estimate tool in Rviz to Localize the Robot in the Map, then use the 2D Nav Goal tool to send a Goal to the Robot.
# - You should see the Turtlebot going to that position in the simulation, and in Rviz you should see the planned path that it follows.

# %% [markdown]
# # SECTION IV: Additional Tasks (Groups of 3)
#
# **If you are in a Group of 3, you must complete the following additional tasks:**
#
# 1. 10% - Use UDRF files to define 5 different geometrical objects, and place them in the environment.
# <ul>
#     <li>Use the following file as an example */home/user/catkin_ws/src/object.urdf* </li>
# <li> <em>Make sure the objects are different from each other and not just the same object in a different color/size.</em> </li> </ul> <br>
# <u> Documentation:</u>
# <ul>
#     <li>Clearly document the commands used to place these objects. </li>
#     <li>Describe the attributes of these objects and how this affects the way the robot interacts with them.</li>
#     <li>Document these objects including screenshots of each in the environment.</li>
# </ul>
#
#         *Hint:*  Ex 1.4
#
# 2. 10% - Using Gazebo and the built in 3D models available in the 'Insert' tab on the left menu, place the following elements into the environment:
# <ul>
#     <li>A maze with the following format</li>
# <li>A small cup or bottle as an additional obstacle in the world</li>
#     <li>Some kind of traffic signal or light</li></ul><br>
# <u> Documentation:</u>
# <ul>
#     <li>Clearly document how you selected and placed these objects. </li>
#     <li>Describe which object you chose to complete each task and why.</li>
#     <li>Document these objects including screenshots of each in the environment. </li>
# </ul>
#
# Save your new world with all added objects by selecting 'File > Save World As' in gazebo, and name it _World{YourGroup}.sdf_ (E.g. WorldAIR01.sdf). Save in your project_planning package and include with your submission. You will be required to demonstrate and explain this section as well in your demo.

# %% [markdown]
# # SECTION V: Project Demo
#
# You will be required to demonstrate your Project as a group. See the AIR Moodle page for details on when the Project Demos will take place.
#
# During the Demo, each group will be given 15-20 minutes to demonstrate their project collectively. Demonstrations will use the simulator + turtleBot.
#
# Attendance is mandatory. If you do not attend the demo, you will receive 0 marks for the entire project.
#
# You may be asked to show:
# -	The robot in movement
# -	Generation of a map
# -	Loading a map
# -	Robot Localisation
# -	Rviz visualisation
# -	Code (Launch and py files) and explain their content
# -	Robot Planning
# -	Incorporation of objects in the environment
# -	Any additional features
# -	Division of Labour/works carried out
# -	Etc

# %% [markdown]
# ## Submission
#
# Download your project files and upload to Moodle in .zip format.
#
# Only one member of the group need submit their project file.
#
# -	**Items to submit**
#     - Folder called ‘GroupName’ containing 3 packages
#     - Project document (The bottom after the ----- line) saved as PDF
# -	All code must be clearly commented
# -	All work should be original
# -   All sources must be cited
# -	You will be required to attend a Demonstration of your project, and explain your work
#
# _(E.g. if your group is AIR01, then create a folder called AIR01, put all three packages into it and your documentation, then compress it to zip and upload to moodle.)_

# %% [markdown]
# # Troubleshooting
#
# <span style="color:red">**NOTE**: If you create your Python file from the terminal, it may happen that it's created without execution permissions. If this happens, ROS won't be able to find it. If this is your case, you can give execution permissions to the file by typing the next command: **chmod +x name_of_the_file.py**</span>
#
# -	Logout for 10 mins if you are experiencing:
#     -	rviz running multiple times
#     -	Unknown processes running in the background
# -	If a map/laser/particlecloud/plan is not visible
#     - Make sure the appropriate node is running
#     - Make sure that the element is subscribed to the correct topic in rviz
# -	If you get the following error, then you will need to publish a transform from the base_link to the map. I would recommend all zeros. Call this file project_planning_transform_base_link_to_map.launch
#     - WARN] [1555404987.356642374, 848.696000000]: Timed out waiting for transform from base_link to map to become available before running costmap, tf error: canTransform: target_frame map does not exist.. canTransform returned after 0.1 timeout was 0.1.
# -	If you get the following error you will need to set up the maps correctly as you are not using the correct map
#     - [ERROR] [1555406187.405033105, 1261.958000000]: None of the points of the global plan were in the local costmap, global plan points too far from robot
# -   *"core service [/rosout] found ERROR: cannot launch node of type [package/script.py]: can't locate node [script.py] in package [package]"*
#     - If you get this error it usually means you created your python script from the terminal, and you need to fix the permissions using  `chmod +x name_of_file.py` (replace name_of_file with the actual name of your file) the file should now appear in green color.

# %% [markdown]
# # APPENDIX: Connect to the Real Robot in RoBoX
# ## This is optional
#
# Additionally, you can use the real TurtleBot3 robot to test your project.
#
# **You can book up to two 30-minute sessions per week.** To do this, follow these simple steps:
#
# ### Step 1: Book a Session
# In the main dashboard, you can book a session by clicking on this icon:
#
# <img src="images/reallab.png"/>
#
# A booking page will appear where you can do two things:
# * Check your bookings
# <img src="images/bookassession.png"/>
# * Make a new booking
# <img src="images/bookings.png"/>
# You can also click on the **BOOK A SESSION** button to make a new one, which will take you to a menu, where you will select:
# * The **Type of Robot** you want to book. For the moment, only TurtleBot3 is available.
# * The Date and Time for your reservation.
# <img src="images/make_reservation_2.png"/>
#
# The **date and times shown are the ones available.** They come in **25 minute slots.** There is also a limitation in the number of bookings per week a user can make. This depends on your particular license and subscription.
# <img src="images/make_reservation_3.png"/>
# <img src="images/make_reservation_4.png"/>
#
# ### Step 2: Launch the RoBox-TurtleBot3 rosject
#
# To have the best experience, you need to launch the rosject with the simulation of TurtleBot3. Chances are, if you're reading this, you've already launched it.
#
# When **one hour or less** is remaining until your booking session, a warning icon will be shown in **the top bar** of The Construct. This means that you have less than an hour to get ready for your session. You will also see the remaining time until your session.
#
# <img src="images/booking_warnings1.png"/>
#
# In case you are inside a rosject, the icon will appear at the bottom line of icons, like in the following image.
#
# <img src="images/warning_4.png"/>
#
# The orange dot will turn into a **red dot** when your booking session has started.
#
# <img src="images/warning_2.png"/>
#
# **Note:** When you are inside your booking, the streaming icon will appear on the desktop inside the rosject:
# <img src="images/stream_icon.png"/>
# <img src="images/RRL_stream.png"/>
#
# ### Step 3: Turn on the RoBoX Connection
#
# Once you are inside the rosject and in your **booked time**, a toggle for **turning on the connection** will appear.
#
# **WARNING: Nothing will appear unless you have a booking. So, if you didn't make one in the dashboard, feel free to do so.**
#
# Now you just have to click on the toggle to connect the desktop environment to the remote lab. This will start the connection process, which lasts for a few seconds.
#
# Once the connection process is finished, the **red dot will change to green** if succesfully connected. Now **any terminal you open will show the topics and services of the real robot**.
#
# <img src="images/connect_robox.gif"/>
#
# Now you should be able to do the following command, getting a list of topics similar to this. It could take around 30 seconds to appear:

# %%
rostopic list

# %%
/battery_state
/cmd_vel
/cmd_vel_rc100
/cv_camera/camera_info
/cv_camera/image_raw
/cv_camera/image_raw/compressed
/cv_camera/image_raw/compressed/parameter_descriptions
/cv_camera/image_raw/compressed/parameter_updates
/cv_camera/image_raw/compressedDepth
/cv_camera/image_raw/compressedDepth/parameter_descriptions
…/odom
/reset
/rosout
/rosout_agg
/rpms
/scan
/sensor_state
/sound
/tf
/tf_static

# %% [markdown]
# **Note:** Take into account that you **will not be able to push git changes when connected to RoBoX because there is no internet connection.** So, to push any changes to your remote gits, you will have to turn off the connection.
#
# You are now connected to the robot! Let's try moving the robot around and seeing the laser and camera in rviz.

# %% [markdown]
# <table style="float:left;background: #407EAF">
# <tr>
# <th>
# <p class="transparent">Execute in WebShell #1</p>
# </th>
# </tr>
# </table>

# %% [markdown]
# Move the robot around: be careful to **NOT EXCEED a linear speed of 0.19 and angular speed of 0.49**. Otherwise, the node will be terminated for safety reasons:

# %%
export TURTLEBOT3_MODEL=burger
roslaunch turtlebot3_teleop turtlebot3_teleop_key.launch

# %% [markdown]
# <table style="float:left;background: #407EAF">
# <tr>
# <th>
# <p class="transparent">Execute in WebShell #2</p>
# </th>
# </tr>
# </table>

# %%
rviz

# %% [markdown]
# You can then add an image and scan elements in the **base_link** frame, which will look something like this:
#
# <img src="images/RRL_scan_cam.png"/>

# %% [markdown]
# ## Ready for your programs!
#
# If you have reached this point, it means that you have a proper connection with the remote real robot lab. **Now you can launch the programs of your project and see the results on a real robot**.
